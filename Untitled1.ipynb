# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

import tempfile
from matplotlib import pyplot as plt

batch_size = 32
img_height = 300
img_width = 300
data_dir = "F:\DEGREE\sem3\CS583\project\data"
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 210 files belonging to 7 classes.
# Using 168 files for training.
# Found 210 files belonging to 7 classes.
# Using 42 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['bear', 'cat', 'dog', 'elephant', 'giraffe', 'horse', 'panda']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 300, 300, 3)
# (32,)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = len(class_names)

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 300, 300, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 300, 300, 16)      448
#
#  max_pooling2d_6 (MaxPoolin  (None, 150, 150, 16)      0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 150, 150, 32)      4640
#
#  max_pooling2d_7 (MaxPoolin  (None, 75, 75, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_8 (MaxPoolin  (None, 37, 37, 64)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 87616)             0
#
#  dense_3 (Dense)             (None, 128)               11214976
#
#  dense_4 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 11239463 (42.88 MB)
# Trainable params: 11239463 (42.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# !mkdir -p saved_model
model.save('saved_model/my_model')
# Out:
# Epoch 1/20
# 6/6 [==============================] - 14s 2s/step - loss: 3.7597 - accuracy: 0.1250 - val_loss: 2.0233 - val_accuracy: 0.1429
# Epoch 2/20
# 6/6 [==============================] - 11s 2s/step - loss: 1.9195 - accuracy: 0.2679 - val_loss: 2.0003 - val_accuracy: 0.0714
# Epoch 3/20
# 6/6 [==============================] - 10s 2s/step - loss: 1.8491 - accuracy: 0.3155 - val_loss: 2.0896 - val_accuracy: 0.1429
# Epoch 4/20
# 6/6 [==============================] - 10s 2s/step - loss: 1.6971 - accuracy: 0.3095 - val_loss: 2.2340 - val_accuracy: 0.0476
# Epoch 5/20
# 6/6 [==============================] - 12s 2s/step - loss: 1.5052 - accuracy: 0.3988 - val_loss: 2.2301 - val_accuracy: 0.1667
# Epoch 6/20
# 6/6 [==============================] - 11s 2s/step - loss: 1.1793 - accuracy: 0.6310 - val_loss: 2.3212 - val_accuracy: 0.0952
# Epoch 7/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.8447 - accuracy: 0.7381 - val_loss: 2.3234 - val_accuracy: 0.1667
# Epoch 8/20
# 6/6 [==============================] - 11s 2s/step - loss: 0.5521 - accuracy: 0.8750 - val_loss: 2.8075 - val_accuracy: 0.1190
# Epoch 9/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.4021 - accuracy: 0.8988 - val_loss: 2.5343 - val_accuracy: 0.1905
# Epoch 10/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.2093 - accuracy: 0.9583 - val_loss: 3.3058 - val_accuracy: 0.1190
# Epoch 11/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.1036 - accuracy: 0.9762 - val_loss: 3.2415 - val_accuracy: 0.1667
# Epoch 12/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0494 - accuracy: 0.9940 - val_loss: 4.7961 - val_accuracy: 0.0952
# Epoch 13/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0322 - accuracy: 0.9940 - val_loss: 3.4376 - val_accuracy: 0.3095
# Epoch 14/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0655 - accuracy: 0.9762 - val_loss: 4.5466 - val_accuracy: 0.0476
# Epoch 15/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0849 - accuracy: 0.9821 - val_loss: 3.4498 - val_accuracy: 0.2381
# Epoch 16/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0459 - accuracy: 0.9881 - val_loss: 4.3674 - val_accuracy: 0.0238
# Epoch 17/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 6.1620 - val_accuracy: 0.0952
# Epoch 18/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 4.0051 - val_accuracy: 0.3095
# Epoch 19/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0176 - accuracy: 0.9940 - val_loss: 6.9350 - val_accuracy: 0.1190
# Epoch 20/20
# 6/6 [==============================] - 10s 2s/step - loss: 0.0310 - accuracy: 0.9940 - val_loss: 3.9284 - val_accuracy: 0.0952
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file saved_model already exists.
# Error occurred while processing: saved_model.
# INFO:tensorflow:Assets written to: saved_model/my_model\assets
# INFO:tensorflow:Assets written to: saved_model/my_model\assets

# %%
new_model = tf.keras.models.load_model('saved_model/my_model')

new_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 300, 300, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 300, 300, 16)      448
#
#  max_pooling2d_6 (MaxPoolin  (None, 150, 150, 16)      0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 150, 150, 32)      4640
#
#  max_pooling2d_7 (MaxPoolin  (None, 75, 75, 32)        0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 64)        18496
#
#  max_pooling2d_8 (MaxPoolin  (None, 37, 37, 64)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 87616)             0
#
#  dense_3 (Dense)             (None, 128)               11214976
#
#  dense_4 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 11239463 (42.88 MB)
# Trainable params: 11239463 (42.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_6 (Sequential)   (None, 300, 300, 3)       0
#
#  rescaling_6 (Rescaling)     (None, 300, 300, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 300, 300, 16)      448
#
#  max_pooling2d_12 (MaxPooli  (None, 150, 150, 16)      0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 150, 150, 32)      4640
#
#  max_pooling2d_13 (MaxPooli  (None, 75, 75, 32)        0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 75, 75, 64)        18496
#
#  max_pooling2d_14 (MaxPooli  (None, 37, 37, 64)        0
#  ng2D)
#
#  dropout_2 (Dropout)         (None, 37, 37, 64)        0
#
#  flatten_4 (Flatten)         (None, 87616)             0
#
#  dense_6 (Dense)             (None, 128)               11214976
#
#  outputs (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 11239463 (42.88 MB)
# Trainable params: 11239463 (42.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
img = tf.keras.utils.load_img(
    "F:\DEGREE\sem3\CS583\project\data\horse\horse2.jpeg", target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "The animal is like a {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 107ms/step
# The animal is like a horse with a 17.23 percent confidence.
